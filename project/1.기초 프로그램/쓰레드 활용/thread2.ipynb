# %%
import threading
import time

def fun_1():
    while True:
        print("processing")
        time.sleep(1.0)
        
t1 = threading.Thread(target=fun_1)
t1.daemon = True # main acting시에만 쓰레드가 작동
t1.start() 

while True:
    print("main acting")
    time.sleep(2.0)
# Out:
# processingmain acting
#
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# main acting
# processing
# processing
# processing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\파이썬\40개의 작품\쓰레드 활용\thread2.ipynb 셀 1 in <cell line: 14>()
# ...
